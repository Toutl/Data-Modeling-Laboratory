# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %% [markdown]
# ```python
# %pip install tensorflow
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

layers = tf.keras.layers
Model = tf.keras.models.Model
# Out:
# 2025-11-25 15:27:58.791349: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-25 15:27:58.833773: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-25 15:28:00.060189: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
with open("../../.style/set_themes.py", "r") as file:
    exec(file.read(), globals())

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
# Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap=rdg_cmap,  # type: ignore
    vmax=1,
    vmin=-1,
    fmt=".2f",
)
plt.title("Correlation Matrix")
plt.show()

# %%
# Correlaciones con el target
correlation_target = df.corr()[["Y1", "Y2"]]
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_target,
    annot=True,
    cmap=rdg_cmap,  # type: ignore
    vmax=1,
    vmin=-1,
    fmt=".2f",
)
plt.title("Correlation Target")
plt.show()

# %%
# Distribucion de las varialbes
sns.pairplot(
    df,
    plot_kws={
        "alpha": 0.1,
        # "s": 20,
        "edgecolor": "none",
    },
)
plt.show()

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[["X1", "X2", "X3", "X4", "X5", "X6", "X7", "X8"]].values
y1 = df["Y1"].values  # Heating Load
y2 = df["Y2"].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(
    X, y1, y2, test_size=0.2, random_state=42
)

# %%
# Estandarizamos los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
Input = layers.Input
Dense = layers.Dense
Dropout = layers.Dropout

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name="input_layer")

# Capas ocultas compartidas
layer_dense1_shared = Dense(64, activation="relu", name="shared_dense_1")(input_layer)
layer_dense2_shared = Dense(32, activation="relu", name="shared_dense_2")(
    layer_dense1_shared
)
layer_dropout1_shared = Dropout(0.2, name="shared_dropout_1")(layer_dense2_shared)

# Estructura para Y1 (Heating Load)
y1_dense_1 = Dense(32, activation="relu", name="y1_dense_1")(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name="y1_dropout")(y1_dense_1)
y1_dense2 = Dense(16, activation="relu", name="y1_dense_2")(y1_dropout)
y1_output = Dense(1, name="y1_output")(y1_dense2)

# Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation="relu", name="y2_dense_1")(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name="y2_dropout")(y2_dense1)
y2_dense3 = Dense(16, activation="relu", name="y2_dense_3")(y2_dropout)
y2_output = Dense(1, name="y2_output")(y2_dense3)
# Out:
# 2025-11-25 15:28:09.218643: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(
    optimizer="adam",
    loss={"y1_output": "mse", "y2_output": "mse"},
    metrics={"y1_output": "mae", "y2_output": "mae"},
)

# Entrenamos el modelo
history = model.fit(
    X_train,
    [y1_train, y2_train],
    epochs=200,
    batch_size=32,
    validation_data=(X_test, [y1_test, y2_test]),
)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1240.3708 - y1_output_loss: 574.0520 - y1_output_mae: 21.4828 - y2_output_loss: 698.2660 - y2_output_mae: 24.2540 - val_loss: 1249.0991 - val_y1_output_loss: 557.0038 - val_y1_output_mae: 21.2663 - val_y2_output_loss: 702.1568 - val_y2_output_mae: 24.5739
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1078.9589 - y1_output_loss: 457.0580 - y1_output_mae: 19.0293 - y2_output_loss: 621.9741 - y2_output_mae: 23.0376 - val_loss: 952.6795 - val_y1_output_loss: 365.0630 - val_y1_output_mae: 16.5100 - val_y2_output_loss: 595.9253 - val_y2_output_mae: 22.4320
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 670.5403 - y1_output_loss: 215.8743 - y1_output_mae: 11.6814 - y2_output_loss: 442.4864 - y2_output_mae: 19.0782 - val_loss: 343.2789 - val_y1_output_loss: 69.6972 - val_y1_output_mae: 6.2135 - val_y2_output_loss: 277.4061 - val_y2_output_mae: 14.4280
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 239.8741 - y1_output_loss: 90.1950 - y1_output_mae: 7.0616 - y2_output_loss: 142.9329 - y2_output_mae: 9.3205 - val_loss: 96.4985 - val_y1_output_loss: 45.2706 - val_y1_output_mae: 4.8066 - val_y2_output_loss: 52.4991 - val_y2_output_mae: 5.1936
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 123.2542 - y1_output_loss: 57.5456 - y1_output_mae: 5.6481 - y2_output_loss: 65.4887 - y2_output_mae: 5.9506 - val_loss: 76.0429 - val_y1_output_loss: 37.0313 - val_y1_output_mae: 4.3151 - val_y2_output_loss: 39.6399 - val_y2_output_mae: 4.4758
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss:
200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.2040 - y1_output_loss: 9.3859 - y1_output_mae: 2.2687 - y2_output_loss: 13.5121 - y2_output_mae: 2.7253 - val_loss: 8.6473 - val_y1_output_loss: 3.2281 - val_y1_output_mae: 1.3855 - val_y2_output_loss: 5.4693 - val_y2_output_mae: 1.6092
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.5742 - y1_output_loss: 8.6394 - y1_output_mae: 2.1570 - y2_output_loss: 12.2183 - y2_output_mae: 2.6404 - val_loss: 12.3152 - val_y1_output_loss: 5.2191 - val_y1_output_mae: 1.7378 - val_y2_output_loss: 7.2385 - val_y2_output_mae: 1.7846
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.1912 - y1_output_loss: 10.0620 - y1_output_mae: 2.3078 - y2_output_loss: 12.6932 - y2_output_mae: 2.6395 - val_loss: 8.6610 - val_y1_output_loss: 2.9310 - val_y1_output_mae: 1.3548 - val_y2_output_loss: 5.8451 - val_y2_output_mae: 1.6667
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.5951 - y1_output_loss: 10.4196 - y1_output_mae: 2.2256 - y2_output_loss: 11.8787 - y2_output_mae: 2.5886 - val_loss: 8.8075 - val_y1_output_loss: 3.3012 - val_y1_output_mae: 1.3926 - val_y2_output_loss: 5.6196 - val_y2_output_mae: 1.5978
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.6558 - y1_output_loss: 10.3156 - y1_output_mae: 2.3230 - y2_output_loss: 12.8830 - y2_output_mae: 2.6678 - val_loss: 7.5116 - val_y1_output_loss: 2.8691 - val_y1_output_mae: 1.3410 - val_y2_output_loss: 4.6883 - val_y2_output_mae: 1.5322
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.9156 - y1_output_loss: 9.9286 - y1_output_mae: 2.2652 - y2_output_loss: 10.8931 - y2_output_mae: 2.4464 - val_loss: 9.1977 - val_y1_output_loss: 3.9029 - val_y1_output_mae: 1.4575 - val_y2_output_loss: 5.3838 - val_y2_output_mae: 1.5874
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.2101 - y1_output_loss: 10.1188 - y1_output_mae: 2.3317 - y2_output_loss: 12.7130 - y2_output_mae: 2.6707 - val_loss: 8.2167 - val_y1_output_loss: 3.0877 - val_y1_output_mae: 1.3118 - val_y2_output_loss: 5.2183 - val_y2_output_mae: 1.5771
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.7417 - y1_output_loss: 10.8002 - y1_output_mae: 2.2468 - y2_output_loss: 11.7702 - y2_output_mae: 2.5525 - val_loss: 7.6323 - val_y1_output_loss: 2.4711 - val_y1_output_mae: 1.1635 - val_y2_output_loss: 5.2332 - val_y2_output_mae: 1.5951
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.0755 - y1_output_loss: 9.3727 - y1_output_mae: 2.2280 - y2_output_loss: 11.3092 - y2_output_mae: 2.5479 - val_loss: 6.9984 - val_y1_output_loss: 2.4105 - val_y1_output_mae: 1.1561 - val_y2_output_loss: 4.6449 - val_y2_output_mae: 1.5224
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.4914 - y1_output_loss: 9.5597 - y1_output_mae: 2.2469 - y2_output_loss: 13.5711 - y2_output_mae: 2.6870 - val_loss: 8.7890 - val_y1_output_loss: 3.7678 - val_y1_output_mae: 1.4678 - val_y2_output_loss: 5.1643 - val_y2_output_mae: 1.6034
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21
200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9848 - y1_output_loss: 7.8982 - y1_output_mae: 2.0275 - y2_output_loss: 9.9080 - y2_output_mae: 2.2877 - val_loss: 7.2573 - val_y1_output_loss: 3.4202 - val_y1_output_mae: 1.4023 - val_y2_output_loss: 3.9421 - val_y2_output_mae: 1.3981
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4372 - y1_output_loss: 7.5773 - y1_output_mae: 2.0076 - y2_output_loss: 10.4982 - y2_output_mae: 2.3527 - val_loss: 8.4230 - val_y1_output_loss: 4.2197 - val_y1_output_mae: 1.5762 - val_y2_output_loss: 4.3391 - val_y2_output_mae: 1.4467
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.4703 - y1_output_loss: 7.5035 - y1_output_mae: 1.9181 - y2_output_loss: 10.0962 - y2_output_mae: 2.3159 - val_loss: 5.9356 - val_y1_output_loss: 1.8590 - val_y1_output_mae: 1.0186 - val_y2_output_loss: 4.1298 - val_y2_output_mae: 1.3816
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.7795 - y1_output_loss: 8.9060 - y1_output_mae: 2.0790 - y2_output_loss: 9.0098 - y2_output_mae: 2.1948 - val_loss: 7.3152 - val_y1_output_loss: 3.3811 - val_y1_output_mae: 1.4332 - val_y2_output_loss: 4.0333 - val_y2_output_mae: 1.4143
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2344 - y1_output_loss: 8.8592 - y1_output_mae: 2.0624 - y2_output_loss: 9.2255 - y2_output_mae: 2.2328 - val_loss: 10.1069 - val_y1_output_loss: 4.8958 - val_y1_output_mae: 1.6837 - val_y2_output_loss: 5.3997 - val_y2_output_mae: 1.6122
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1969 - y1_output_loss: 8.4331 - y1_output_mae: 1.9780 - y2_output_loss: 10.0882 - y2_output_mae: 2.2690 - val_loss: 5.7025 - val_y1_output_loss: 1.9060 - val_y1_output_mae: 1.0511 - val_y2_output_loss: 3.8762 - val_y2_output_mae: 1.3600
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.8263 - y1_output_loss: 9.4778 - y1_output_mae: 2.0752 - y2_output_loss: 9.6453 - y2_output_mae: 2.3162 - val_loss: 6.1701 - val_y1_output_loss: 2.1251 - val_y1_output_mae: 1.0825 - val_y2_output_loss: 4.1367 - val_y2_output_mae: 1.4142
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.4949 - y1_output_loss: 7.0337 - y1_output_mae: 1.9121 - y2_output_loss: 10.1547 - y2_output_mae: 2.3170 - val_loss: 6.3474 - val_y1_output_loss: 2.8007 - val_y1_output_mae: 1.2764 - val_y2_output_loss: 3.6107 - val_y2_output_mae: 1.3480
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9719 - y1_output_loss: 7.5027 - y1_output_mae: 1.9643 - y2_output_loss: 10.7985 - y2_output_mae: 2.4647 - val_loss: 6.0942 - val_y1_output_loss: 1.9831 - val_y1_output_mae: 1.0701 - val_y2_output_loss: 4.2107 - val_y2_output_mae: 1.3738
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0995 - y1_output_loss: 7.1801 - y1_output_mae: 1.8973 - y2_output_loss: 10.4988 - y2_output_mae: 2.3025 - val_loss: 8.9711 - val_y1_output_loss: 5.0391 - val_y1_output_mae: 1.6915 - val_y2_output_loss: 4.0536 - val_y2_output_mae: 1.3499
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.4675 - y1_output_loss: 7.5933 - y1_output_mae: 1.9522 - y2_output_loss: 8.6934 - y2_output_mae: 2.1831 - val_loss: 7.1496 - val_y1_output_loss: 2.8503 - val_y1_output_mae: 1.2365 - val_y2_output_loss: 4.3930 - val_y2_output_mae: 1.3654
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6959 - y1_output_loss: 6.6685 - y1_output_mae: 1.8732 - y2_output_loss: 10.8060 - y2_output_mae: 2.3091 - val_loss: 4.8756 - val_y1_output_loss: 1.6433 - val_y1_output_mae: 0.9698 - val_y2_output_loss: 3.2707 - val_y2_output_mae: 1.3052
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.8506 - y1_output_loss: 7.1704 - y1_output_mae: 1.9034 - y2_output_loss: 10.1603 - y2_output_mae: 2.3330 - val_loss: 5.9121 - val_y1_output_loss: 2.1635 - val_y1_output_mae: 1.0942 - val_y2_output_loss: 3.8018 - val_y2_output_mae: 1.3784
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8868 - y1_output_loss: 8.0308 - y1_output_mae: 2.0649 - y2_output_loss: 8.6225 - y2_output_mae: 2.1203 - val_loss: 5.6612 - val_y1_output_loss: 1.5605 - val_y1_output_mae: 0.9519 - val_y2_output_loss: 4.2011 - val_y2_output_mae: 1.3757
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0322 - y1_output_loss: 6.7909 - y1_output_mae: 1.8808 - y2_output_loss: 9.1119 - y2_output_mae: 2.1724 - val_loss: 11.0857 - val_y1_output_loss: 6.9365 - val_y1_output_mae: 1.9967 - val_y2_output_loss: 4.3099 - val_y2_output_mae: 1.4095
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9224 - y1_output_loss: 8.3125 - y1_output_mae: 2.0774 - y2_output_loss: 8.9275 - y2_output_mae: 2.2329 - val_loss: 6.5171 - val_y1_output_loss: 1.9400 - val_y1_output_mae: 1.0587 - val_y2_output_loss: 4.6752 - val_y2_output_mae: 1.4603
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.5862 - y1_output_loss: 6.8591 - y1_output_mae: 1.8999 - y2_output_loss: 9.2553 - y2_output_mae: 2.2381 - val_loss: 5.9608 - val_y1_output_loss: 2.6231 - val_y1_output_mae: 1.2224 - val_y2_output_loss: 3.4155 - val_y2_output_mae: 1.3057
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9784 - y1_output_loss: 8.1043 - y1_output_mae: 2.0280 - y2_output_loss: 9.8049 - y2_output_mae: 2.2851 - val_loss: 8.9911 - val_y1_output_loss: 4.9062 - val_y1_output_mae: 1.6372 - val_y2_output_loss: 4.2559 - val_y2_output_mae: 1.4076
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9815 - y1_output_loss: 7.3912 - y1_output_mae: 1.8830 - y2_output_loss: 10.2396 - y2_output_mae: 2.3673 - val_loss: 5.2999 - val_y1_output_loss: 1.7983 - val_y1_output_mae: 0.9844 - val_y2_output_loss: 3.5782 - val_y2_output_mae: 1.2829
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.5329 - y1_output_loss: 6.6460 - y1_output_mae: 1.8898 - y2_output_loss: 9.4764 - y2_output_mae: 2.2444 - val_loss: 4.6547 - val_y1_output_loss: 1.4657 - val_y1_output_mae: 0.9001 - val_y2_output_loss: 3.2371 - val_y2_output_mae: 1.3271
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.0512 - y1_output_loss: 6.6742 - y1_output_mae: 1.8745 - y2_output_loss: 10.9220 - y2_output_mae: 2.3875 - val_loss: 6.8127 - val_y1_output_loss: 3.3405 - val_y1_output_mae: 1.3531 - val_y2_output_loss: 3.5068 - val_y2_output_mae: 1.4909
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.6930 - y1_output_loss: 6.8700 - y1_output_mae: 1.8891 - y2_output_loss: 9.5646 - y2_output_mae: 2.2701 - val_loss: 6.4803 - val_y1_output_loss: 1.9694 - val_y1_output_mae: 1.0457 - val_y2_output_loss: 4.5972 - val_y2_output_mae: 1.4984

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose="0")

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 6.4803
# Heating Loss: 1.9694, Cooling Loss: 4.5972
# Test MAE for Heating Load: 1.0457 Wh
# Test MAE for Cooling Load: 1.4984 Wh

# %%
import matplotlib.pyplot as plt

print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="Total Training Loss")
plt.plot(history.history["val_loss"], label="Total Validation Loss")
plt.plot(history.history["y1_output_loss"], label="Heating Training Loss")
plt.plot(history.history["val_y1_output_loss"], label="Heating Validation Loss")
plt.plot(history.history["y2_output_loss"], label="Cooling Training Loss")
plt.plot(history.history["val_y2_output_loss"], label="Cooling Validation Loss")
plt.title("Model Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history["y1_output_mae"], label="Heating Training MAE")
plt.plot(history.history["val_y1_output_mae"], label="Heating Validation MAE")
plt.plot(history.history["y2_output_mae"], label="Cooling Training MAE")
plt.plot(history.history["val_y2_output_mae"], label="Cooling Validation MAE")
plt.title("Model MAE over Epochs")
plt.xlabel("Epochs")
plt.ylabel("MAE (Wh)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score


def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse


# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(
    y1_train, y_train_pred_heating
)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(
    y2_train, y_train_pred_cooling
)
print("=== Train Performance ===")
print(
    f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}"
)
print(
    f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}"
)

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(
    y1_test, y_test_pred_heating
)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(
    y2_test, y_test_pred_cooling
)
print("\n=== Test Performance ===")
print(
    f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}"
)
print(
    f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}"
)
# Out:
# === Train Performance ===
# Heating Load: R²=0.985, MAE=0.930, RMSE=1.114
# Cooling Load: R²=0.960, MAE=1.357, RMSE=1.376
#
# === Test Performance ===
# Heating Load: R²=0.981, MAE=1.046, RMSE=1.186
# Cooling Load: R²=0.951, MAE=1.498, RMSE=1.456

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import KFold

models = tf.keras.models


def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))

    # Capas compartidas
    x = layers.Dense(128, activation="relu")(input_layer)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.2)(x)

    # Heating
    h = layers.Dense(64, activation="relu")(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation="relu")(h)
    y1 = layers.Dense(1, name="heating_output")(h)

    # Cooling
    c = layers.Dense(64, activation="relu")(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation="relu")(c)
    y2 = layers.Dense(1, name="cooling_output")(c)

    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer="adam", loss="mse")
    return model

# %%
from numpy import sqrt
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
import gc

# KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")

    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df["Y1"][train_idx], df["Y1"][val_idx]
    y_train_cool, y_val_cool = df["Y2"][train_idx], df["Y2"][val_idx]

    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)

    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool], epochs=80, batch_size=32, verbose=0 # type: ignore
    )

    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose="0")

    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()

    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))

    # Cleaning
    tf.keras.backend.clear_session()
    del model
    gc.collect()
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x73a055edd9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x73a04054e840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(
    f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
    f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}"
)
print(
    f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
    f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}"
)
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.928±0.025, MAE=2.098, RMSE=2.646
# Cooling Load: R2=0.900±0.039, MAE=2.143, RMSE=2.947

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random

from sklearn.model_selection import train_test_split

optimizers = tf.keras.optimizers  # type: ignore

df = pd.read_csv("ENB2012_data.csv")
X_full = df[["X1", "X2", "X3", "X4", "X5", "X6", "X7", "X8"]].values
y1_full = df["Y1"].values
y2_full = df["Y2"].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = (
    train_test_split(X_full, y1_full, y2_full, test_size=0.2, random_state=42)
)


# Definimos el contructor del modelo
def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))

    # compartidas
    x = input_layer
    for i in range(params["n_shared_layers"]):
        x = layers.Dense(params["n_shared_units"], activation="relu")(x)
        x = layers.Dropout(params["dropout_rate"])(x)

    # Heating
    h = layers.Dense(params["n_shared_units"] // 2, activation="relu")(x)
    y1 = layers.Dense(1, name="heating_output")(h)

    # Cooling
    c = layers.Dense(params["n_shared_units"] // 2, activation="relu")(x)
    y2 = layers.Dense(1, name="cooling_output")(c)

    model = models.Model(inputs=input_layer, outputs=[y1, y2])

    opt = optimizers.Adam(learning_rate=params["learning_rate"])
    model.compile(
        optimizer=opt,  # type: ignore
        loss={"heating_output": "mse", "cooling_output": "mse"},
        metrics={"heating_output": "mae", "cooling_output": "mae"},
    )

    return model


# Espacio para el random search

param_distributions = {
    "n_shared_layers": [1, 2, 3],
    "n_shared_units": [32, 64, 128, 256],
    "dropout_rate": [0.0, 0.1, 0.2, 0.3, 0.4],
    "learning_rate": [1e-4, 5e-4, 1e-3, 5e-3],
    "batch_size": [16, 32, 64],
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")

    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = (
        train_test_split(
            X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
        )
    )

    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs,
        [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50,
        batch_size=params["batch_size"],
        verbose=0,  # type: ignore
    )

    val_loss = np.mean(history.history["val_loss"][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
# Validation Loss: 51.7478
#
# Trial 2/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 23.6803
#
# Trial 3/5 with params: {'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.0001, 'batch_size': 64}
# Validation Loss: 80.5194
#
# Trial 4/5 with params: {'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 16}
# Validation Loss: 16.3796
#
# Trial 5/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 15.4635
#
#  Results
#  1) Val Loss=15.4635 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.005, 'batch_size': 32}
#  2) Val Loss=16.3796 | Params={'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 16}
#  3) Val Loss=23.6803 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 16}
#  4) Val Loss=51.7478 | Params={'n_shared_layers': 3, 'n_shared_units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
#  5) Val Loss=80.5194 | Params={'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.0001, 'batch_size': 64}
#
#  Mejor configuracion:
# {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.005, 'batch_size': 32}
# Validation Loss: 15.4635

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
